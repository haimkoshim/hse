# %%
print("   _~_       _~_       _~_    ")
print("  (o o)     (o o)     (o o)   ")
print(" /  V  \   /  V  \   /  V  \  ")
print("/(  _  )\ /(  _  )\ /(  _  )\ ")
print("  ^^ ^^     ^^ ^^     ^^ ^^   ")
# Out:
#    _~_       _~_       _~_
#   (o o)     (o o)     (o o)
#  /  V  \   /  V  \   /  V  \
# /(  _  )\ /(  _  )\ /(  _  )\
#   ^^ ^^     ^^ ^^     ^^ ^^

# %%
a = input()
words = a.split()
print('Количество символов : ', len(a))
print('Количество слов : ' , len(words))
# Out:
# yaaay i did that shiiit
# Количество символов :  23
# Количество слов :  5

# %%
sentence= "Lorem ipsum dolor sit amet"
print(sentence[3])     #третий символ этой строки.
print(sentence[-23])   #предпоследний символ этой строки.
print(sentence[0:5])   #первые пять символов этой строки.
print(sentence[:-2])   #всю строку, кроме последних двух символов.
print(sentence[::2])   #все символы с четными индексами 
print(sentence[1::2])  #все символы с нечетными индексами
print(sentence[::-1])  #все символы в обратном порядке.
print(sentence[::-2])  #все символы строки через один в обратном порядке, начиная с последнего.
print(len(a))          #выведите длину данной строки.
# Out:
# e
# e
# Lorem
# Lorem ipsum dolor sit am
# Lrmismdlrstae
# oe pu oo i mt
# tema tis rolod muspi meroL
# 24

# %%
s = input("Вася,вводи свое слово: ") 

if s.lower() != s[::-1].lower():
    print ("no")
else: 
    print ("yes")
    
s = input("Вася,вводи свое слово: ") 

if s.lower() != s[::-1].lower():
    print ("no")
else: 
    print ("yes")
# Out:
# Вася,вводи свое слово: потоп
# yes
# Вася,вводи свое слово: василий
# no

# %%
text= ["законы физики рядом с черной дырой уже не работают в том представлении в котором мы привыкли" 
"пространство время искривляется и все события протекают уже совсем по другому"
"словно пылесос черная дыра поглощает все что находится около нее планеты астероиды свет и прочее" 
"ранее считалось что черная дыра ничего не излучает но как доказал стивен хокинг черная дыра излучает антивещество" 
"то есть поедает вещество и выделяет антивещество" 
"ранее думали что если кинуть в черную дыру человека то ему труба порвет на субатомы" 
"но как оказалось по некоторым уравнениям есть определенные траектории путешествия сквозь черную дыру чтоб чувствовать себя нормально" 
"правда не ясно что будет за ней другой мир или ничего" 
"область вокруг черной дыры которая интересна называется горизонтом событий" 
"если туда полететь не зная волшебное уравнение то будет конечно не очень" 
"наблюдатель будет видеть как космический корабль влетает в горизонт событий и крайне медленно потом отдаляется пока не застынет в центре"
"у самого же космонавта дела будут идти совсем по другому"
"искривленное пространство будет лепить из него как из пластилина различные формы пока наконец не разорвет все на субатомы" 
"но для внешнего наблюдателя космонавт навсегда останется улыбающимся и махающим в иллюминатор застывшим изображением"]

alsotext = ['законы', 'физики', 'рядом', 'с', 'черной', 'дырой', 'уже', 'не', 'работают', 'в', 'том', 'представлении', 
        'в', 'котором', 'мы', 'привыкли', 'пространство', 'время', 'искривляется', 'и', 'все', 'события', 'протекают', 
        'уже', 'совсем', 'по', 'другому', 'словно', 'пылесос', 'черная', 'дыра', 'поглощает', 'все', 'что', 'находится', 
        'около', 'нее', 'планеты', 'астероиды', 'свет', 'и', 'прочее', 'ранее', 'считалось', 'что', 'черная', 'дыра', 'ничего',
        'не', 'излучает', 'но', 'как', 'доказал', 'стивен', 'хокинг', 'черная', 'дыра', 'излучает', 'антивещество', 'то', 'есть', 
        'поедает', 'вещество', 'и', 'выделяет', 'антивещество', 'ранее', 'думали', 'что', 'если', 'кинуть', 'в', 'черную', 'дыру', 
        'человека', 'то', 'ему', 'труба', 'порвет', 'на', 'субатомы', 'но', 'как', 'оказалось', 'по', 'некоторым', 'уравнениям', 
        'есть', 'определенные', 'траектории', 'путешествия', 'сквозь', 'черную', 'дыру', 'чтоб', 'чувствовать', 'себя', 'нормально', 
        'правда', 'не', 'ясно', 'что', 'будет', 'за', 'ней', 'другой', 'мир', 'или', 'ничего', 'область', 'вокруг', 'черной', 'дыры', 
        'которая', 'интересна', 'называется', 'горизонтом', 'событий', 'если', 'туда', 'полететь', 'не', 'зная', 'волшебное', 'уравнение', 
        'то', 'будет', 'конечно', 'не', 'очень', 'наблюдатель', 'будет', 'видеть', 'как', 'космический', 'корабль', 'влетает', 'в', 'горизонт', 
        'событий', 'и', 'крайне', 'медленно', 'потом', 'отдаляется', 'пока', 'не', 'застынет', 'в', 'центре', 'у', 'самого', 'же', 'космонавта', 
        'дела', 'будут', 'идти', 'совсем', 'по', 'другому', 'искривленное', 'пространство', 'будет', 'лепить', 'из', 'него', 'как', 'из', 'пластилина', 
        'различные', 'формы', 'пока', 'наконец', 'не', 'разорвет', 'все', 'на', 'субатомы', 'но', 'для', 'внешнего', 'наблюдателя', 'космонавт', 'навсегда', 
        'останется', 'улыбающимся', 'и', 'махающим', 'в', 'иллюминатор', 'застывшим', 'изображением']


s = input("Введите слово: ") 

if s not in alsotext:
    print("oops,nothing here :c, here you go,")
    text.append(s)
    print(text)
else:
    print("о да, оно есть, так еще вот столько раз")
#     print(text.count(alsotext))
#     print(s(count(s)in alsotext)
# короче, если слова нет, то все работает, а вот как сделать другое условие я не знаю :c
# Out:
# Введите слово: о
# oops,nothing here :c, here you go,
# ...

# %%
peace
